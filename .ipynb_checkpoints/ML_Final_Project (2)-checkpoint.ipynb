# %% [markdown]
# # Bayesian Machine Learning Final Project
# ### Diyu Zheng, Taylor Rohrich, Congxin (David) Xu

# %%
import pandas as pd
import pymc3 as pm
import sklearn.model_selection
import sklearn
from pandas_profiling import ProfileReport
import arviz as az
import seaborn as sns
import numpy as np
# Out:
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# C:\Users\Apoptoxin\anaconda3\lib\site-packages\theano\configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %% [markdown]
# ## Data Cleaning

# %%
# Data Read In and Preview
data = pd.read_csv('small.csv', skiprows=1, skipfooter=2, engine='python')
#data = pd.read_csv('C:/Users/Apoptoxin/Desktop/DS6014 Baysian Machine Learning/Project/LoanStats3d_securev1.csv', skiprows=1, skipfooter=2, engine='python')
data.head()
# Out:
#    60626564  Unnamed: 1  20000  20000.1  20000.0   36 months    5.32%   602.3  \
# 0  58672463         NaN   5000     5000   5000.0   36 months   12.69%  167.73
# 1  56119683         NaN   7200     7200   7200.0   36 months   11.53%  237.53
# 2  66410614         NaN  21475    21475  21475.0   60 months   19.99%  568.84
# 3  44563840         NaN  20950    20950  20950.0   60 months   19.52%  549.47
# 4  47614152         NaN  12500    12500  12500.0   36 months    6.00%  389.49
#
#    A  A1  ... Unnamed: 140 Unnamed: 141 Unnamed: 142  N.1 Unnamed: 144  \
# 0  C  C2  ...          NaN          NaN          NaN    N          NaN
# 1  B  B5  ...          NaN          NaN          NaN    N          NaN
# 2  E  E4  ...          NaN          NaN          NaN    N          NaN
# 3  E  E3  ...          NaN          NaN          NaN    N          NaN
# 4  B  B2  ...          NaN          NaN          NaN    N          NaN
#
#   Unnamed: 145 Unnamed: 146 Unnamed: 147 Unnamed: 148  Unnamed: 149
# 0          NaN          NaN          NaN          NaN           NaN
# 1          NaN          NaN          NaN          NaN           NaN
# 2          NaN          NaN          NaN          NaN           NaN
# 3          NaN          NaN          NaN          NaN           NaN
# 4          NaN          NaN          NaN          NaN           NaN
#
# [5 rows x 150 columns]

# %%
# Dimensions: 420k + rows and 150 columns
data.shape
data = data.sample(frac=.005)
data.to_csv('small.csv',index=False)

# %%
data = pd.read_csv('small.csv')

# %%
# Identify the response variable
data.loan_status.unique()
# Out:
# array(['Fully Paid', 'Charged Off', 'Current', 'In Grace Period'],
#       dtype=object)

# %%
# Distribution of the response variable
data.loan_status.value_counts()
# Out:
# Fully Paid         1616
# Charged Off         429
# Current              59
# In Grace Period       1
# Name: loan_status, dtype: int64

# %%
# For Simplicity, we are only going to assume that all data are either 'Default' or `Fully Paid`
data.loc[data['loan_status'] == 'Charged Off', 'loan_status'] = 'Default'
data.loc[data['loan_status'] != 'Default', 'loan_status'] = 'Fully Paid'
data.loan_status.value_counts()
# Out:
# Fully Paid    1676
# Default        429
# Name: loan_status, dtype: int64

# %%
profile = ProfileReport(data_selected,title='Profiling Report',html={'style':{'full_width':True}},minimal =False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2bdcf326c311> in <module>
# ----> 1 profile = ProfileReport(data_selected,title='Profiling Report',html={'style':{'full_width':True}},minimal =False)
#
# NameError: name 'data_selected' is not defined

# %% [markdown]
# ### Split training and test data
# We are going to split the original data into 2 parts, training data and testing data. The Bayesian Logistic Regression model and the Naive Bayes model will only uses the training data to train the model and later, use the test data to generate forecast accuracy metrics and compare the performance with each other.

# %%
train, test = sklearn.model_selection.train_test_split(data, test_size=0.2)
train.shape
# Out:
# (1684, 150)

# %%
test.shape
# Out:
# (421, 150)

# %%
train
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 1348  65018356        NaN      30000        30000          29900.0
# 2047  40385955        NaN      26000        26000          26000.0
# 1761  48736426        NaN      12000        12000          12000.0
# 363   67266635        NaN      20000        20000          20000.0
# 164   62266496        NaN      13500        13500          13500.0
# ...        ...        ...        ...          ...              ...
# 1816  51496970        NaN      16900        16900          16900.0
# 121   53091283        NaN      20000        20000          20000.0
# 1877  40372716        NaN      12000        12000          12000.0
# 405   60705362        NaN      10000        10000          10000.0
# 1922  56110587        NaN      25000        25000          24975.0
#
#             term int_rate  installment grade sub_grade  ...  \
# 1348   60 months   12.05%       668.10     C        C1  ...
# 2047   60 months    8.67%       535.57     B        B1  ...
# 1761   36 months    8.18%       377.04     B        B1  ...
# 363    60 months    8.38%       409.18     B        B1  ...
# 164    60 months    9.99%       286.77     B        B3  ...
# ...          ...      ...          ...   ...       ...  ...
# 1816   60 months   27.31%       519.19     G        G2  ...
# 121    60 months    9.99%       424.85     B        B3  ...
# 1877   36 months   13.66%       408.16     C        C3  ...
# 405    36 months    6.24%       305.31     A        A2  ...
# 1922   60 months   18.55%       642.34     E        E2  ...
#
#      orig_projected_additional_accrued_interest  \
# 1348                                        NaN
# 2047                                        NaN
# 1761                                        NaN
# 363                                         NaN
# 164                                         NaN
# ...                                         ...
# 1816                                        NaN
# 121                                         NaN
# 1877                                        NaN
# 405                                         NaN
# 1922                                        NaN
#
#      hardship_payoff_balance_amount hardship_last_payment_amount  \
# 1348                            NaN                          NaN
# 2047                            NaN                          NaN
# 1761                            NaN                          NaN
# 363                             NaN                          NaN
# 164                             NaN                          NaN
# ...                             ...                          ...
# 1816                            NaN                          NaN
# 121                             NaN                          NaN
# 1877                            NaN                          NaN
# 405                             NaN                          NaN
# 1922                            NaN                          NaN
#
#       debt_settlement_flag debt_settlement_flag_date settlement_status  \
# 1348                     N                       NaN               NaN
# 2047                     N                       NaN               NaN
# 1761                     N                       NaN               NaN
# 363                      Y                  Jun-2020          COMPLETE
# 164                      N                       NaN               NaN
# ...                    ...                       ...               ...
# 1816                     N                       NaN               NaN
# 121                      N                       NaN               NaN
# 1877                     Y                  Sep-2017          COMPLETE
# 405                      N                       NaN               NaN
# 1922                     N                       NaN               NaN
#
#      settlement_date settlement_amount settlement_percentage  settlement_term
# 1348             NaN               NaN                   NaN              NaN
# 2047             NaN               NaN                   NaN              NaN
# 1761             NaN               NaN                   NaN              NaN
# 363         Dec-2019            2864.0                 42.87              6.0
# 164              NaN               NaN                   NaN              NaN
# ...              ...               ...                   ...              ...
# 1816             NaN               NaN                   NaN              NaN
# 121              NaN               NaN                   NaN              NaN
# 1877        Jun-2017            2700.0                 43.01              1.0
# 405              NaN               NaN                   NaN              NaN
# 1922             NaN               NaN                   NaN              NaN
#
# [1684 rows x 150 columns]

# %% [markdown]
# ## Bayesian Logistic Regression

# %% [markdown]
# For Bayesian Logistic Regression we will consider a full model and  smaller models, removing correlated / statistically insignificant predictors.

# %%
# Select potential Predictors
# Changes these to proper names
column_selected = ['loan_status', # response
                   'annual_inc','chargeoff_within_12_mths',
                  'avg_cur_bal','int_rate',
                 'num_actv_bc_tl','num_actv_rev_tl', 
                   'grade','home_ownership','addr_state'] # categorical variable
    #grade: 7;home_ownership: 3; addr_state: 49
data_selected = train[column_selected]
data_selected.head()
# Out:
#      loan_status  annual_inc  chargeoff_within_12_mths  avg_cur_bal int_rate  \
# 1348  Fully Paid     95000.0                         0        28890   12.05%
# 2047  Fully Paid     65000.0                         0        10058    8.67%
# 1761  Fully Paid     60000.0                         0         3245    8.18%
# 363      Default    108000.0                         0         4581    8.38%
# 164      Default     32500.0                         0         2682    9.99%
#
#       num_actv_bc_tl  num_actv_rev_tl grade home_ownership addr_state
# 1348               6                7     C            OWN         NJ
# 2047               2                2     B            OWN         KY
# 1761               5                7     B           RENT         MN
# 363                4                4     B           RENT         WA
# 164                7                8     B           RENT         WI

# %%
dist_lookup = dict(zip(data_selected['addr_state'].unique(), range(len(data_selected['addr_state'].unique()))))
data_selected['addr_state'] = data_selected['addr_state'].replace(dist_lookup)
# Out:
# C:\Users\Apoptoxin\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dist_lookup2 = dict(zip(data_selected['home_ownership'].unique(), range(len(data_selected['home_ownership'].unique()))))
data_selected['home_ownership'] = data_selected['home_ownership'].replace(dist_lookup2)
# Out:
# C:\Users\Apoptoxin\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
grade_map = {'A':0,'B':1,'C':2,'D':3,'E':4,'F':5,'G':6}
data_selected =  data_selected.replace({'grade':grade_map})

# %%
# remove the percent % from column interest rate
data_selected['int_rate'] = data_selected['int_rate'].str.replace('%','').astype(float)

# %%
# set the binary result loan_status to 
data_selected['loan_status'] = data_selected['loan_status'].map({'Fully Paid':0,'Default':1})

# %%
# Scale data
def scale_column(col):
    return (col-np.mean(col))/np.std(col)
for column in data_selected.columns:
    if column not in ['loan_status','grade','home_ownership','addr_state','']:
        data_selected[column] = scale_column(data_selected[column])

# %%
data_selected.head()
# Out:
#       loan_status  annual_inc  chargeoff_within_12_mths  avg_cur_bal  \
# 1348            0    0.338739                 -0.109632     1.098805
# 2047            0   -0.222634                 -0.109632    -0.195120
# 1761            0   -0.316196                 -0.109632    -0.663234
# 363             1    0.582001                 -0.109632    -0.571439
# 164             1   -0.830787                 -0.109632    -0.701917
#
#       int_rate  num_actv_bc_tl  num_actv_rev_tl  grade  home_ownership  \
# 1348 -0.150645        0.987090         0.325213      2               0
# 2047 -0.952692       -0.777517        -1.140682      1               0
# 1761 -1.068965        0.545938         0.325213      1               1
# 363  -1.021507        0.104787        -0.554324      1               1
# 164  -0.639467        1.428242         0.618392      1               1
#
#       addr_state
# 1348           0
# 2047           1
# 1761           2
# 363            3
# 164            4

# %%
correlation = data_selected.corr()
from matplotlib import pyplot as plt
plt.figure(figsize = (8,8))
sns.heatmap(correlation,annot =True,center = 0)
plt.title('Correlation Between Personal Economic Indicators')
# Out:
# Text(0.5, 1.0, 'Correlation Between Personal Economic Indicators')

# %%
fig, ax = plt.subplots()

sns.kdeplot(data_selected[data_selected['loan_status']==1]['annual_inc'], shade=True, color="blue", label="default", ax=ax)
sns.kdeplot(data_selected[data_selected['loan_status']==0]['annual_inc'], shade=True, color="green", label="fully paid", ax=ax)

ax.set_xlabel("Annual Income")
ax.set_ylabel("Density")

fig.suptitle("Annual Income vs. Default rate for loans")

# %%
fig, ax = plt.subplots()

sns.kdeplot(data_selected[data_selected['loan_status']==1]['int_rate'], shade=True, color="blue", label="default", ax=ax)
sns.kdeplot(data_selected[data_selected['loan_status']==0]['int_rate'], shade=True, color="green", label="fully paid", ax=ax)

ax.set_xlabel("Interest rate")
ax.set_ylabel("Density")

fig.suptitle("Interest Rate vs. Default rate for loans")
# Out:
# Text(0.5, 0.98, 'Interest Rate vs. Default rate for loans')

# %%
fig, ax = plt.subplots()

sns.kdeplot(data_selected[data_selected['loan_status']==1]['avg_cur_bal'], shade=True, color="blue", label="default", ax=ax)
sns.kdeplot(data_selected[data_selected['loan_status']==0]['avg_cur_bal'], shade=True, color="green", label="fully paid", ax=ax)

ax.set_xlabel("Average current balance")
ax.set_ylabel("Density")

fig.suptitle("Average current balance vs. Default rate for loans")
# Out:
# Text(0.5, 0.98, 'Average current balance vs. Default rate for loans')

# %%
fig, ax = plt.subplots()

sns.kdeplot(data_selected[data_selected['loan_status']==1]['chargeoff_within_12_mths'], shade=True, color="blue", label="default", ax=ax)
sns.kdeplot(data_selected[data_selected['loan_status']==0]['chargeoff_within_12_mths'], shade=True, color="green", label="fully paid", ax=ax)

ax.set_xlabel("Chargeoff within 12 months")
ax.set_ylabel("Density")

fig.suptitle("Chargeoff within 12 months vs. Default rate for loans")
# Out:
# Text(0.5, 0.98, 'Chargeoff within 12 months vs. Default rate for loans')

# %%
fig, ax = plt.subplots()

sns.catplot("home_ownership", hue="loan_status", data=data_selected, kind="count", 
            palette={1:"blue", 0:"green"}, ax=ax)

ax.set_xlabel("home_ownership Class")
ax.legend(handles=color_patches)

fig.suptitle("home owndership Class vs. Default");
# Out:
# C:\Users\Apoptoxin\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Apoptoxin\anaconda3\lib\site-packages\seaborn\categorical.py:3762: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-929daf89ab54> in <module>
#       7 ax.set_xlabel("home_ownership Class")
#       8
# ----> 9 ax.legend(handles=color_patches)
#      10
#      11 fig.suptitle("home owndership Class vs. Default");
#
# NameError: name 'color_patches' is not defined

# %%
loan_home  = data_selected.groupby(['loan_status','home_ownership']).size().reset_index()
loan_home = loan_home.rename({0:'count'},axis =1)
loan_home
# Out:
#    loan_status  home_ownership  count
# 0            0               0    137
# 1            0               1    664
# 2            0               2    535
# 3            1               0     43
# 4            1               1    133
# 5            1               2    172

# %%
plt.figure(figsize = (15,8))
myplot = sns.barplot(x = 'loan_status', y ='count', hue = 'home_ownership', data = loan_home,orient = 'v')
# Out:
# Text(0.5, 1.0, "Number of people's attitude towards the statement")

# %% [markdown]
# ## Constructing Models

# %% [markdown]
# ### hierarchical model (addr_state)

# %%
num_state = len(data_selected['addr_state'].unique())
state = data_selected['addr_state']
log_default = np.log(data_selected['loan_status'] + 0.1).values

with pm.Model() as hierarchical_logistic_model:

    # Priors
    mu_a = pm.Normal('mu_a', mu=0., sd=1)
    sigma_a = pm.Exponential("sigma_a",  0.5)
    mu_b = pm.Normal('mu_b', mu=0., sd=1)
    sigma_b = pm.Exponential("sigma_b",  0.5)

    # Random intercepts
    a = pm.Normal('intercept', mu=mu_a, sd=sigma_a, shape=num_state)
    # Random slopes
    b1 = pm.Normal('annual_inc', mu=mu_b, sd=sigma_b, shape=num_state) 
    b2 = pm.Normal('chargeoff_within_12_mths', mu=mu_b, sd=sigma_b, shape=num_state)
    b3 = pm.Normal('avg_cur_bal', mu=mu_b, sd=sigma_b, shape=num_state)
    b4 = pm.Normal('int_rate', mu=mu_b, sd=sigma_b, shape=num_state)
    b5 = pm.Normal('num_actv_bc_tl', mu=mu_b, sd=sigma_b, shape=num_state)
    b6 = pm.Normal('num_actv_rev_tl', mu=mu_b, sd=sigma_b, shape=num_state)

    
    y_hat = a[state] + b1[state] * data_selected['annual_inc'] + b2[state] * data_selected['chargeoff_within_12_mths']+  b3[state] * data_selected['avg_cur_bal'] + b4[state] * data_selected['int_rate'] + b5[state] * data_selected['num_actv_bc_tl'].values + b6[state] * data_selected['num_actv_rev_tl']
    
    sigma_y = pm.Uniform('sigma_y',lower = 0, upper = 100)
    # Data likelihood
    y_like = pm.Normal('y_like', mu= y_hat, sd = sigma_y, observed=log_default)

# %%
pm.model_to_graphviz(hierarchical_logistic_model)

# %%
with pm.Model() as hierarchical_logistic_model: 
    trace_hierarchical_sample = pm.sample(1000, step = pm.NUTS(target_accept = 0.95), cores = 4, tune=2000)
    pm.traceplot(trace_hierarchical_sample)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma_y, num_actv_rev_tl, num_actv_bc_tl, int_rate, avg_cur_bal, chargeoff_within_12_mths, annual_inc, intercept, sigma_b, mu_b, sigma_a, mu_a]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='15' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.12% [15/12000 04:46<63:35:55 Sampling 4 chains, 0 divergences]
#     </div>

# %%
with pm.Model() as manual_logistic_model:
    az.plot_forest(trace_hierarchical_sample)

# %% [markdown]
# ### full model

# %%
# Full Model Setup
with pm.Model() as full_model_sample:
    y = data_selected['loan_status']
    # Model Betas as uninformed gaussians
    b0 = pm.Normal('intercept', mu=0, sd=1e5) 
    #b1 = pm.Normal('addr_state', mu=0, sd=1e5) 
    b2 = pm.Normal('annual_inc', mu=0, sd=1e5) 
    b3 = pm.Normal('chargeoff_within_12_mths', mu=0, sd=1e5)
   # b4 = pm.Normal('home_ownership', mu=0, sd=1e5)
    b5 = pm.Normal('avg_cur_bal', mu=0, sd=1e5)
   # b6 = pm.Normal('expDefaultRate', mu=0, sd=1e5)
    b7 = pm.Normal('int_rate', mu=0, sd=1e5)
   # b8 = pm.Normal('isIncV', mu=0, sd=1e5)
    b9 = pm.Normal('num_actv_bc_tl', mu=0, sd=1e5)
    b10 = pm.Normal('num_actv_rev_tl', mu=0, sd=1e5)
    #b11 = pm.Normal('purpose', mu=0, sd=1e5)
    # Calculate mu
    mu = b0 + pm.math.dot(data_selected["annual_inc"], b2)+  pm.math.dot(data_selected["chargeoff_within_12_mths"], b3)+ \
    pm.math.dot(data_selected["avg_cur_bal"], b5)+  pm.math.dot(data_selected["int_rate"], b7) + \
   pm.math.dot(data_selected["num_actv_bc_tl"], b9) + \
    pm.math.dot(data_selected["num_actv_rev_tl"], b10)
    # Use inv logit function
    theta = pm.Deterministic('theta',  pm.invlogit(mu))
    # Calculate bernoulli
    yl = pm.Bernoulli('Yl', p=theta, observed=y)
    trace_full_sample = pm.sample(2000, tune=1000, init='adapt_diag', cores =4)
    pm.traceplot(trace_full_sample)
pm.model_to_graphviz(full_model_sample)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [num_actv_rev_tl, num_actv_bc_tl, int_rate, avg_cur_bal, chargeoff_within_12_mths, annual_inc, intercept]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:12<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 23 seconds.

# %%
az.plot_forest(trace_full_sample, var_names=['annual_inc','chargeoff_within_12_mths','avg_cur_bal','int_rate','num_actv_bc_tl','num_actv_rev_tl','intercept']);
# Out:
# /opt/miniconda3/envs/python3/lib/python3.8/site-packages/arviz/data/io_pymc3.py:87: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(

# %%
soft_classification = trace_full_sample['theta'].mean(axis=0)
hard_classification = np.array(list(map(lambda x: 1 if x >= .5 else 0,soft_classification)))
n = len(hard_classification)
np.sum(hard_classification == data_selected['loan_status']) /n
# Out:
# 0.7986935866983373

# %%
sklearn.metrics.confusion_matrix(hard_classification, data_selected['loan_status'])
# Out:
# array([[1323,  317],
#        [  22,   22]])

# %% [markdown]
# ## Reduced Logistic Regression Model

# %%
# Full Model Setup
with pm.Model() as reduced_model_sample:
    y = data_selected['loan_status']
    # Model Betas as uninformed gaussians
    b0 = pm.Normal('intercept', mu=0, sd=1e5) 
    b1 = pm.Normal('annual_inc', mu=0, sd=1e5) 
    b2 = pm.Normal('avg_cur_bal', mu=0, sd=1e5)
    b3 = pm.Normal('int_rate', mu=0, sd=1e5)
    # Calculate mu
    mu = b0 + pm.math.dot(data_selected["annual_inc"], b1)+ \
    pm.math.dot(data_selected["avg_cur_bal"], b2)+  pm.math.dot(data_selected["int_rate"], b3)
    # Use inv logit function
    theta = pm.Deterministic('theta',  pm.invlogit(mu))
    # Calculate bernoulli
    yl = pm.Bernoulli('Yl', p=theta, observed=y)
    trace_reduced_sample = pm.sample(2000, tune=1000, init='adapt_diag', cores =4)
    pm.traceplot(trace_reduced_sample)
pm.model_to_graphviz(reduced_model_sample)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [int_rate, avg_cur_bal, annual_inc, intercept]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:05<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 16 seconds.

# %%
soft_classification = trace_reduced_sample['theta'].mean(axis=0)
hard_classification = np.array(list(map(lambda x: 1 if x >= .5 else 0,soft_classification)))
n = len(hard_classification)
np.sum(hard_classification == data_selected['loan_status']) /n
# Out:
# 0.7969121140142518

# %%
sklearn.metrics.confusion_matrix(hard_classification, data_selected['loan_status'])
# Out:
# array([[1320,  317],
#        [  25,   22]])

# %% [markdown]
# ## Reduced Logistic Regression Model

# %% [markdown]
# ## Bayesian Model Averaging

# %%
# Model comparisons with WAIC and weights

cmp_df = az.compare({'model_full':trace_full_sample, 'model_reduced':trace_reduced_sample,'model_hierarchical': hier_trace_sample},
                    ic = 'WAIC',
                    method='BB-pseudo-BMA')
# Model weights
cmp_df
# Out:
# /opt/miniconda3/envs/python3/lib/python3.8/site-packages/arviz/stats/stats.py:149: UserWarning:
# The scale is now log by default. Use 'scale' argument or 'stats.ic_scale' rcParam if you rely on a specific value.
# A higher log-score (or a lower deviance) indicates a model with better predictive accuracy.
#   warnings.warn(
# /opt/miniconda3/envs/python3/lib/python3.8/site-packages/arviz/data/io_pymc3.py:87: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(
# /opt/miniconda3/envs/python3/lib/python3.8/site-packages/arviz/stats/stats.py:1425: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(
# /opt/miniconda3/envs/python3/lib/python3.8/site-packages/arviz/data/io_pymc3.py:87: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(
# /opt/miniconda3/envs/python3/lib/python3.8/site-packages/arviz/stats/stats.py:1425: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   warnings.warn(
#               rank     waic   p_waic   d_waic    weight       se      dse  \
# model_reduced    0 -781.907  4.53816        0  0.821317  23.1447        0
# model_full       1 -783.862  7.38795  1.95534  0.178683  23.0062  1.30775
#
#               warning waic_scale
# model_reduced    True        log
# model_full       True        log

# %%
# Computing predictions by combining the models using the WAIC weights

#np.exp(-0.5*waic_p[0])/(np.exp(-0.5*waic_l[0]) + np.exp(-0.5*waic_p[0]))
# or use the value given in the table
w_full= cmp_df.loc['model_full','weight']
w_reduced= cmp_df.loc['model_reduced','weight']

weights = [w_full,w_reduced]

# %%
# BMA Model
y_bma = pm.sample_posterior_predictive_w(traces = [trace_full_sample,trace_reduced_sample],
                                        samples=1000,
                                        models=[full_model_sample, reduced_model_sample],
                                        weights=weights)
# Full Model
y_full = pm.sample_posterior_predictive_w(traces = [trace_full_sample],
                                        samples=1000,
                                         models=[full_model_sample])
# Model without adiposity
y_m2 = pm.sample_posterior_predictive_w(traces = [trace_reduced_sample],
                                        samples=1000,
                                        models=[ reduced_model_sample])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 00:00<00:00]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 00:00<00:00]
#     </div>

# %%
az.plot_kde(trace_full_sample['theta'].mean(axis=0), plot_kwargs={'color': 'C1'}, label='full model',)
az.plot_kde(trace_reduced_sample['theta'].mean(axis=0), plot_kwargs={'color': 'C1'}, label='reduced model',)
theta_bma = trace_full_sample['theta'].mean(axis=0)*weights[0]+ trace_reduced_sample['theta'].mean(axis=0)*weights[1]
az.plot_kde(theta_bma, plot_kwargs={'color': 'C1'}, label='bma model',)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Naive Bayes Classifier
# The Naive Bayes Classifier model is going to focus on the following variables:
# - `term`: Term of the load. "36 months" or "60 months"
# - `grade`: Load Grade, A to G
# - `sub_grade`: Each letter grade will have 6 subgrace, A1 to A6
# - `emp_title`: Title of the employment of the borrower
# - `emp_length`: The length of the employment
# - `home_ownership`: Whether the borrows own a home.
# - `purpose`: The purpose of taking the load
# - `addr_state`: The state of the residence for the borrower.

# %%
# Select the categorical variable from the training data 
naive_column = [ 'loan_status', 'term','grade','sub_grade','emp_length','home_ownership','purpose','addr_state']
train_naive = train[naive_column].fillna('NA')
train_naive.head()
# Out:
#        loan_status        term  ...             purpose addr_state
# 417489  Fully Paid   60 months  ...  debt_consolidation         TX
# 199300     Default   60 months  ...  debt_consolidation         MD
# 135569  Fully Paid   60 months  ...         credit_card         PA
# 30741   Fully Paid   36 months  ...  debt_consolidation         IN
# 343896     Default   36 months  ...      small_business         MD
#
# [5 rows x 8 columns]

# %%
# Add Column Names to each of the values within that column
d_train = dict()
d_train['loan_status'] = list(train_naive.iloc[:, 0])

for i in range(1, len(train_naive.keys())):
    d_train[train_naive.keys()[i]] = list(train_naive.keys()[i] + "_" + train_naive.iloc[:, i])

new_train = pd.DataFrame(data = d_train)
new_train.head()
# Out:
#   loan_status             term  ...                     purpose     addr_state
# 0  Fully Paid  term_ 60 months  ...  purpose_debt_consolidation  addr_state_TX
# 1     Default  term_ 60 months  ...  purpose_debt_consolidation  addr_state_MD
# 2  Fully Paid  term_ 60 months  ...         purpose_credit_card  addr_state_PA
# 3  Fully Paid  term_ 36 months  ...  purpose_debt_consolidation  addr_state_IN
# 4     Default  term_ 36 months  ...      purpose_small_business  addr_state_MD
#
# [5 rows x 8 columns]

# %%
# Perform the same data transformation on Test data
test_naive = test[naive_column].fillna('NA')
d_test = dict()
d_test['loan_status'] = list(test_naive.iloc[:, 0])

for i in range(1, len(test_naive.keys())):
    d_test[test_naive.keys()[i]] = list(test_naive.keys()[i] + "_" + test_naive.iloc[:, i])

new_test = pd.DataFrame(data = d_test)
new_test.head()
# Out:
#   loan_status             term  ...                     purpose     addr_state
# 0  Fully Paid  term_ 36 months  ...         purpose_credit_card  addr_state_WA
# 1  Fully Paid  term_ 36 months  ...              purpose_moving  addr_state_NY
# 2  Fully Paid  term_ 36 months  ...  purpose_debt_consolidation  addr_state_NJ
# 3  Fully Paid  term_ 36 months  ...  purpose_debt_consolidation  addr_state_CT
# 4  Fully Paid  term_ 60 months  ...  purpose_debt_consolidation  addr_state_MS
#
# [5 rows x 8 columns]

# %%
# For Topic = Fully Paid
# Create a train document of words
train_FP_document = new_train[new_train['loan_status'] == 'Fully Paid']. \
    iloc[:, list(range(1,len(new_train.keys())))].values.ravel()

# Count the number of features occured in training data for Fully Paid
train_FP_count = dict()
for i in train_FP_document:
    if i not in train_FP_count:
        train_FP_count[i] = 0
    else:
        train_FP_count[i] += 1
        
# Get the total number of words occured and number of unique features
FP_total = sum(train_FP_count.values())
FP_count = len(train_FP_count.keys())

# Define alpha 
alpha = 1.5

# Caculate the likelihood for each word in topic = edible
for index, value in enumerate(train_FP_count):
    train_FP_count[value] = (train_FP_count[value] + alpha) / \
          (FP_total + alpha * FP_count)

# %%
# For Topic = Default
# Create a train document of words
train_DT_document = new_train[new_train['loan_status'] == 'Default']. \
    iloc[:, list(range(1,len(new_train.keys())))].values.ravel()

# Count the number of features occured in training data for Default
train_DT_count = dict()
for i in train_DT_document:
    if i not in train_DT_count:
        train_DT_count[i] = 0
    else:
        train_DT_count[i] += 1
        
# Get the total number of words occured and number of unique features
DT_total = sum(train_DT_count.values())
DT_count = len(train_DT_count.keys())

# Caculate the likelihood for each word in topic = edible
for index, value in enumerate(train_DT_count):
    train_DT_count[value] = (train_DT_count[value] + alpha) / \
          (DT_total + alpha * DT_count)

# %%
# Calculate the Posterior Probability for Test Data
new_test_FP_post = list()
new_test_DT_post = list()

for row in range(0, len(new_test)):
    FP_post = 1
    DT_post = 1
    for col in range(1, len(new_test.columns)):
        if (new_test.iloc[row, col] in train_FP_count): 
            FP_post = FP_post * \
              train_FP_count[new_test.iloc[row, col]]
        else:
            FP_post = FP_post * \
                (0 + alpha) / (FP_total + alpha * FP_count)
        
        if (new_test.iloc[row, col] in train_DT_count): 
            DT_post = DT_post * \
                train_DT_count[new_test.iloc[row, col]]
        else:
            DT_post = DT_post * \
                (0 + alpha) / (DT_total + alpha * DT_count)

    new_test_FP_post += [FP_post]   
    new_test_DT_post += [DT_post]

# %%
# Create a confusion matrix to evaluate prediction accuracy
actual = list()
predict = list()
for i in range(0, len(new_test)):
    if new_test.iloc[i,0] == 'Default':
        actual += [1]
    else:
        actual += [0]
        
    if new_test_DT_post[i] > new_test_FP_post[i]:
        predict += [1]
    else:
        predict += [0]

df_confusion = pd.crosstab(pd.Series(actual, name='actual'), pd.Series(predict, name='predict'))    
df_confusion
# Out:
# predict      0      1
# actual
# 0        41856  26344
# 1         5248  10771

# %% [markdown]
# The total accuracy for the Naive Bayes Model is $$\frac{ 41856 + 10771}{41856 + 10771 + 5248 + 26344} = 62.49\%$$
